# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusCarneiro17/CalcMODII/blob/main/Elei%C3%A7%C3%A3o_MODII.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Desenvolva um código que simule uma eleição com três candidatos.
# - candidato_X => 889
# - candidato_Y => 847
# - candidato_Z => 515
# - branco => 0
#
# O código deve perguntar se deseja finalizar a votação depois do voto. Caso o número do voto não corresponda a nenhum candidato ou seja branco, ele deve ser tratado como nulo. Se for inserido um texto ao invés de número, o código deve retornar uma mensagem para votar novamente.
#
# Quando a votação for finalizada, o código deverá mostrar o vencedor, aquele com o maior número de votos e, também, a quantidade de votos de cada candidato, os brancos e nulos
#
# Trabalhe esse código em seu IDE, suba ele para sua conta no GitHub e compartilhe o link desse projeto no campo ao lado para que outros desenvolvedores possam analisá-lo.
#
# Obs: A urna não considera a possibilidade de empate entre os candidatos.

# %%
def urna (cand):
  votosX = 0
  votosY = 0
  votosZ = 0
  votosN = 0
  rodar = 1
  while rodar != 0 :
    try:

      cand = int(input("Insira o número do seu candidato: "))

      if (cand == 889):
        print ("cand_X => 889")
        confirma = input("Digite sim para finalizar o seu voto: ")
        if (confirma == "sim"):
          votosX = votosX + 1
          fim = input("chegou ao fim da apuração? ")  
          if (fim == "sim"):
            print (" ")
          else:
            continue

      elif (cand == 847):
        print ("cand_Y => 847")
        confirma = input("Digite sim para finalizar o seu voto: ")
        if (confirma == "sim"):
          votosY = votosY + 1
          fim = input("chegou ao fim da apuração? ")  
          if (fim == "sim"):
            print (" ")
          else:
            continue
      elif (cand == 515):
        print ("cand_Z => 515")
        confirma = input("Digite sim para finalizar o seu voto: ")
        if (confirma == "sim"):
          votosZ = votosZ + 1
          fim = input("chegou ao fim da apuração? ")  
          if (fim == "sim"):
            print (" ")
          else:
            continue
        
      else:
        print ("Você está anulando seu voto")
        confirma = (input("Digite sim para finalizar o seu voto: "))
        if (confirma == "sim"):
          votosN = votosN + 1 
          fim = input("chegou ao fim da apuração? ")  
          if (fim == "sim"):
            print (" ")
          else:
            continue
    except:
      print ("Vote novamente")
        
    if (fim == "sim"):
      if (votosX > votosY) and (votosY > votosZ):
        print ("Candidato_X venceu a eleição com: ",votosX, "votos")
        print ("Candidato_Y ficou em segundo lugar com ",votosY, "votos")
        print ("Candidato_Z ficou em terceiro com ",votosZ, "votos")
        print ("Votos brancos e nulos: ",votosN, "votos")
      elif (votosX > votosZ) and (votosZ < votosY): 
        print ("Candidato_X venceu a eleição com: ",votosX, "votos")
        print ("Candidato_Z ficou em segundo lugar com ",votosZ, "votos")
        print ("Candidato_Y ficou em terceiro com ",votosY, "votos")
        print ("Votos brancos e nulos: ",votosN, "votos")
      elif (votosY > votosX) and (votosX > votosZ): 
        print ("Candidato_Y venceu a eleição com: ",votosY, "votos")
        print ("Candidato_X ficou em segundo lugar com ",votosX, "votos")
        print ("Candidato_Z ficou em terceiro com ",votosZ, "votos")
        print ("Votos brancos e nulos: ",votosN, "votos")
      elif (votosY > votosZ) and (votosZ > votosX): 
        print ("Candidato_Y venceu a eleição com: ",votosY, "votos")
        print ("Candidato_Z ficou em segundo lugar com ",votosX, "votos")
        print ("Candidato_X ficou em terceiro com ",votosX, "votos")
        print ("Votos brncos e nulos: ",votosN, "votos")
      elif (votosZ > votosX) and (votosX > votosY): 
        print ("Candidato_Z venceu a eleição com: ",votosZ, "votos")
        print ("Candidato_X ficou em segundo lugar com ",votosX, "votos")
        print ("Candidato_Y ficou em terceiro com ",votosY, "votos")
        print ("Votos brncos e nulos: ",votosN, "votos")
      else: 
        print ("Candidato_Z venceu a eleição com: ",votosZ, "votos")
        print ("Candidato_Y ficou em segundo lugar com ",votosY, "votos")
        print ("Candidato_X ficou em terceiro com ",votosX, "votos")
        print ("Votos brancos e nulos: ",votosN, "votos")
      rodar = 0


Apur = urna(0)
# Out:
# Insira o número do seu candidato: 2
# Você está anulando seu voto
# Digite sim para finalizar o seu voto: sim
# chegou ao fim da apuração? não
# Insira o número do seu candidato: 847
# cand_Y => 847
# Digite sim para finalizar o seu voto: sim
# chegou ao fim da apuração? não
# Insira o número do seu candidato: 847
# cand_Y => 847
# Digite sim para finalizar o seu voto: não
# Insira o número do seu candidato: 847
# cand_Y => 847
# Digite sim para finalizar o seu voto: sim
# chegou ao fim da apuração? não
# Insira o número do seu candidato: 889
# cand_X => 889
# Digite sim para finalizar o seu voto: sim
# chegou ao fim da apuração? não
# Insira o número do seu candidato: 515
# cand_Z => 515
# Digite sim para finalizar o seu voto: não
# Insira o número do seu candidato: 515
# cand_Z => 515
# Digite sim para finalizar o seu voto: sim
# chegou ao fim da apuração? não
# Insira o número do seu candidato: 515
# cand_Z => 515
# Digite sim para finalizar o seu voto: sim
# ...
